# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load the data from the path
data_path = "/content/drive/MyDrive/smile-annotations-final.csv"
news_data = pd.read_csv(data_path, error_bad_lines=False)

# Show data information
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3084 entries, 0 to 3083
# Data columns (total 3 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   611857364396965889                                                             3084 non-null   int64
#  1   @aandraous @britishmuseum @AndrewsAntonio Merci pour le partage! @openwinemap  3084 non-null   object
#  2   nocode                                                                         3084 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 72.4+ KB

# %% [markdown]
# **Import necessary libraries**

# %%
# !pip install transformers sentencepiece
from transformers import MarianTokenizer, MarianMTModel

# %%
from transformers import BertTokenizer, BertForSequenceClassification

# Define the model name
model_name = 'bert-base-uncased'

# Get the tokenizer
tokenizer = BertTokenizer.from_pretrained(model_name)

# Instantiate the model
model = BertForSequenceClassification.from_pretrained(model_name)

# Print the model name
print("Model Name:", model.config.name_or_path)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model Name: bert-base-uncased

# %% [markdown]
# Sentiment analysis

# %%
from transformers import pipeline
# Extract the text data from the specified column
text_data = df['611857364396965889'].astype(str).tolist()  # Convert to string and then to list

# Define the model checkpoint for sentiment analysis
model_checkpoint = "distilbert-base-uncased-finetuned-sst-2-english"

# Load the sentiment analysis model pipeline
sentiment_analysis_model = pipeline(task="sentiment-analysis", model=model_checkpoint)

# Perform sentiment analysis on each text
sentiment_results = sentiment_analysis_model(text_data)

# Display or save the sentiment analysis results
for text, result in zip(text_data, sentiment_results):
    print("Text:", text)
    print("Predicted Sentiment:", result['label'], "(Confidence:", result['score'], ")")
    print("")
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# Predicted Sentiment: NEGATIVE (Confidence: 0.729047954082489 )
#
# Text: 611591164962177024
# Predicted Sentiment: NEGATIVE (Confidence: 0.5048906803131104 )
#
# Text: 614025148639809536
# Predicted Sentiment: NEGATIVE (Confidence: 0.675646960735321 )
#
# Text: 610813197210243073
# Predicted Sentiment: NEGATIVE (Confidence: 0.8546313047409058 )
#
# Text: 610479100126478336
# Predicted Sentiment: NEGATIVE (Confidence: 0.8400084376335144 )
#
# Text: 614734340359102464
# Predicted Sentiment: NEGATIVE (Confidence: 0.6035507917404175 )
#
# Text: 610521564791074817
# Predicted Sentiment: NEGATIVE (Confidence: 0.804263174533844 )
#
# Text: 612946396254236672
# ...
